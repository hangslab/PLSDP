# %%
import os
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import multilabel_confusion_matrix, confusion_matrix
import math
from itertools import product
import argparse
import sys
from utils_gru import *
import calendar
import time
# Out:
# C:\Users\vipuser\.conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\vipuser\.conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\vipuser\.conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\vipuser\.conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\vipuser\.conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\vipuser\.conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def process_eachseq(seq,pssmfile,mask_seq,new_pssms):
    if os.path.exists(pssmfile):  #如果pssm文件存在
        print("found " + pssmfile + "\n")  #输出找到pssm文件+换行
        pssm = readPSSM(pssmfile)  #读取pssm文件
    else:  #否则
        print("using Blosum62\n")  #输出使用Blosum62+换行
        pssm = convertSampleToBlosum62(seq)  #把Blosum62矩阵当作pssm用
    pssm = pssm.astype(float)  #对pssm的数据类型转换为浮点型
    PhyChem = convertSampleToPhysicsVector_pca(seq)  #将样本转化为物理向量
    pssm = np.concatenate((PhyChem, pssm), axis=1)  #物化指标和pssm对应行进行数组拼接
    seql = len(seq)   #序列长度  
    if seql <= 1000:  #如果序列长度小于等于1000
        padnum = 1000 - seql  #pad大小为1000-序列长度
        padmatrix = np.zeros([padnum, 25])  #pad矩阵为行数为padnum，列数为25的全0矩阵，即用0填充不足的地方
        pssm = np.concatenate((pssm, padmatrix), axis=0)  #物化指标和pssm进行数组拼接 
        new_pssms.append(pssm)  #新的pssm空列表中添加pssm矩阵
        mask_seq.append(gen_mask_mat(seql, padnum))  #mask序列空列表添加gen_mask矩阵，序列长度为行数，padnum为列数？？？
    else:  #如果序列长度大于1000
        pssm = np.concatenate((pssm[0:500, :], pssm[seql - 500:seql, :]), axis=0)  #pssm矩阵为前500行和后500行矩阵的拼接
        new_pssms.append(pssm)  #新的pssm空列表中添加pssm矩阵
        mask_seq.append(gen_mask_mat(1000, 0))  #mask序列空列表添加1000行0列的？？？gen_mask矩阵

# %%
def endpad(seqfile, labelfile, pssmdir="", npzfile = ""): #定义endpad(序列文件，标签文件，pssm路径，npz文件)
    if not os.path.exists(npzfile):  #如果npz文件不存在，建立新的pssm空列表，标签空列表，mask序列空列表，id空列表
        new_pssms = []
        labels = []
        mask_seq = []
        ids=[]
        seqs=[]
        f = open(seqfile, "r")  #f为打开序列文件
        f2 = open(labelfile, "r")  #f2为打开标签文件
        line = f.readline()  #读取序列文件的第一行
        while line != '':
            pssmfile = pssmdir + line[1:].strip() + "_pssm.txt"  #pssm文件名=pssm地址+id名+_pssm.txt
            if line[0] == '>':  #如果该行第一个字符为>
                id = line.strip()[1:]  #id为去掉>的字符
                ids.append(id)   #在id空列表中添加id
            label = f2.readline().strip()  #标签为f2（标签文件）中去掉首尾空格的内容
            labels.append(label)  #在标签空列表中添加标签
            seq = f.readline().strip()  #第一次seq为第2行的内容，实际seq为>行的下一行
            #seql = len(seq)   #序列长度  
            process_eachseq(seq,pssmfile,mask_seq,new_pssms)
            line = f.readline()  #继续读取下一行，即>行
        x = np.array(new_pssms)  #把new_pssms列表变为数组，赋给x
        y = [convertlabels_to_categorical(i) for i in labels]  #把标签列表转化为类别(i)
        y = np.array(y)  #再把类别转化为数组
        mask = np.array(mask_seq)  #把mask_seq（标注的序列？）转化为数组
        np.savez(npzfile, x=x, y=y, mask=mask, ids=ids)  #保存多个数组到同一个文件中,保存格式是.npz
        return [x, y, mask,ids]  #返回pssm矩阵，类别，标注序列，名字id
    else:  #如果上述都存在，直接转化为数组
        mask = np.load(npzfile)['mask']
        x = np.load(npzfile)['x']
        y = np.load(npzfile)['y']
        ids=np.load(npzfile)['ids']
        return [x, y, mask,ids]

# %%
def train_MULocDeep(lv1_dir,lv2_dir,pssm_dir,output_dir,foldnum):
    # get small data
    [train_x, train_y, train_mask, train_ids] = endpad(
        lv2_dir+"lv2_train_fold" + str(foldnum) + "_seq",
        lv2_dir+"lv2_train_fold" + str(foldnum) + "_label",
        pssm_dir,
        "E:/论文真的非常重要请好好学习/MULocDeep-master/MULocDeep-master_new/data/UniLoc-train-20nr/8folds/lv2_train_fold"+str(foldnum)+"_seq.npz")
    [val_x, val_y, val_mask,val_ids] = endpad(
        lv2_dir+"lv2_val_fold" + str(foldnum) + "_seq",
        lv2_dir+"lv2_val_fold" + str(foldnum) + "_label",
        pssm_dir,
        "E:/论文真的非常重要请好好学习/MULocDeep-master/MULocDeep-master_new/data/UniLoc-train-20nr/8folds/lv2_val_fold"+str(foldnum)+"_seq.npz")

    # get big data
    [train_x_big, train_y_big, train_mask_big, train_ids_big] = endpad(
        lv1_dir + "lv1_train_fold" + str(foldnum) + "_seq",
        lv1_dir + "lv1_train_fold" + str(foldnum) + "_label",
        pssm_dir,
        "E:/论文真的非常重要请好好学习/MULocDeep-master/MULocDeep-master_new/data/UniLoc-train-20nr/8folds/lv1_train_fold" + str(foldnum) + "_seq.npz")

    [val_x_big, val_y_big, val_mask_big, val_ids_big] = endpad(
        lv1_dir + "lv1_val_fold" + str(foldnum) + "_seq",
        lv1_dir + "lv1_val_fold" + str(foldnum) + "_label",
        pssm_dir,
        "E:/论文真的非常重要请好好学习/MULocDeep-master/MULocDeep-master_new/data/UniLoc-train-20nr/8folds/lv1_val_fold" + str(foldnum) + "_seq.npz")

    batch_size = 128
    print("doing " + str(foldnum) + "th fold")
    model_big, model_small = singlemodel(train_x)  #模型为singlemodel

    filepath_acc_big_lv1 = output_dir+"fold" + str(
        foldnum) + "_big_lv1_acc-weights.hdf5"  # -improvement-{epoch:02d}-{val_loss:.2f}.hdf5"

    filepath_acc_small_lv2 = output_dir+"fold" + str(
        foldnum) + "_small_lv2_acc-weights.hdf5"  # -improvement-{epoch:02d}-{val_loss:.2f}.hdf5"

    filepath_loss_big_lv1 = output_dir+"fold" + str(
        foldnum) + "_big_lv1_loss-weights.hdf5"  # -improvement-{epoch:02d}-{val_loss:.2f}.hdf5"

    filepath_loss_small_lv2 = output_dir+"fold" + str(
        foldnum) + "_small_lv2_loss-weights.hdf5"  # -improvement-{epoch:02d}-{val_loss:.2f}.hdf5"


    checkpoint_acc_big_lev1 = ModelCheckpoint(filepath_acc_big_lv1, monitor='val_accuracy', save_best_only=True,
                                          mode='max',
                                          save_weights_only=True, verbose=1)

    checkpoint_acc_small_lev2 = ModelCheckpoint(filepath_acc_small_lv2, monitor='val_lev2_accuracy', save_best_only=True,
                                          mode='max',
                                          save_weights_only=True, verbose=1)
    
    checkpoint_loss_big_lev1 = ModelCheckpoint(filepath_loss_big_lv1, monitor='val_loss', save_best_only=True,
                                          mode='min',
                                          save_weights_only=True, verbose=1)
    
    checkpoint_loss_small_lev2 = ModelCheckpoint(filepath_loss_small_lv2, monitor='val_lev2_loss', save_best_only=True,
                                          mode='min',
                                          save_weights_only=True, verbose=1)
    
    
    for i in range(80):
        # train small model
        print("epoch "+str(i)+"\n")
        fitHistory_batch_small = model_small.fit([train_x, train_mask.reshape(-1, 1000, 1)],
                                                 [train_y,getTrue4out1(train_y)],
                                                 batch_size=batch_size, epochs=1,
                                                 validation_data=(
                                                 [val_x, val_mask.reshape(-1, 1000, 1)], [val_y,getTrue4out1(val_y)]),
                                                 callbacks=[checkpoint_acc_small_lev2,checkpoint_loss_small_lev2],verbose=1)
        
        # train big model  
        fitHistory_batch_big = model_big.fit([train_x_big, train_mask_big.reshape(-1, 1000, 1)],
                                             [train_y_big,getTrue4out1(train_y_big)],  #为何大模型没有train_y_big
                                             batch_size=batch_size, epochs=1,  #等于1？？
                                             validation_data=(
                                             [val_x_big, val_mask_big.reshape(-1, 1000, 1)], [val_y_big,getTrue4out1(val_y_big)]),  #也没有val_y_big
                                             callbacks=[checkpoint_acc_big_lev1,checkpoint_loss_big_lev1], verbose=1)

# %%
def train_var(input_var,pssm_dir,output_dir,foldnum):
    # get small data
    [train_x,train_y,train_mask,train_ids]=endpad(input_var+"deeploc_40nr_train_fold"+str(foldnum)+"_seq",
                                        input_var+"deeploc_40nr_train_fold"+str(foldnum)+"_label",
                                        pssm_dir,
                                        "D:/deeploc/deeploc_40nr_8folds/train_fold"+str(foldnum)+"_seq.npz")
    [val_x,val_y,val_mask,val_ids]=endpad(input_var+"deeploc_40nr_val_fold"+str(foldnum)+"_seq",
                                  input_var+"deeploc_40nr_val_fold"+str(foldnum)+"_label",
                                  pssm_dir,
                                  "D:/deeploc/deeploc_40nr_8folds/val_fold"+str(foldnum)+"_seq.npz")
    batch_size = 128
    print("doing " + str(foldnum) + "th fold")
    model = var_model(train_x)   #这里的模型是var_model

    filepath_acc = output_dir+"fold" + str(foldnum) + "acc-weights.hdf5"  # -improvement-{epoch:02d}-{val_loss:.2f}.hdf5"
    checkpoint_acc = ModelCheckpoint(filepath_acc, monitor='val_accuracy', save_best_only=True, mode='max',
                                 save_weights_only=True, verbose=1)
    fitHistory_batch = model.fit([train_x,train_mask.reshape(-1,1000,1)],getTrue4out1(train_y),
                                 batch_size=batch_size, epochs=20,
                                 validation_data=([val_x,val_mask.reshape(-1,1000,1)], getTrue4out1(val_y)),
                                 callbacks=[checkpoint_acc],verbose=1)

# %%
 '''我们常常可以把argparse的使用简化成下面四个步骤
       1：import argparse
       2：parser = argparse.ArgumentParser()
       3：parser.add_argument()
       4：parser.parse_args()
       上面四个步骤解释如下：首先导入该模块；然后创建一个解析对象；然后向该对象中添加你要关注的命令行参数和选项，
       每一个add_argument方法对应一个你要关注的参数或选项；最后调用parse_args()方法进行解析；解析成功之后即可使用'''
    
def main():
    #加default
    # description= 这个参数简要描述这个程度做什么以及怎么做
    parser=argparse.ArgumentParser(
        description='MULocDeep: interpretable protein localization classifier at sub-cellular and sub-organellar levels')
    #MULocDeep_model  UniLoc-train-20nr
    #--lv1_input_dir/--lv2_input_dir 亚细胞训练数据，包含8折蛋白质序列和标记  需自己添加
    parser.add_argument('--lv1_input_dir', dest='lv1_dir', type=str, 
                        default="E:/论文真的非常重要请好好学习/2021.2 MULocDeep-master/MULocDeep-master_new/data/UniLoc-train-20nr/8folds",
                        help='sub-cellular training data, contains 8 folds protein sequences and labels', required=False)
    parser.add_argument('--lv2_input_dir', dest='lv2_dir', type=str,
                       default="E:/论文真的非常重要请好好学习/2021.2 MULocDeep-master/MULocDeep-master_new/data/UniLoc-train-20nr/8folds",
                       help='sub-cellular training data, contains 8 folds protein sequences and labels', required=False)
    #--MULocDeep_model 添加它来训练MULocDeep模型，否则训练一个var模型
    parser.add_argument('--MULocDeep_model', dest='modeltype', action='store_true',  #要触发，目前没触发，所以训练了DeepLoc
                        #如果是store_false,则默认值是True，如果是store_true,则默认值是False  
                        help='Add this to train the MULocDeep model, otherwise train a variant model', required=False)
    #--model_output 受过训练的模型存储的目录的名称  需自己添加
    parser.add_argument('--model_output', dest='outputdir', type=str, 
                       default="E:/论文真的非常重要请好好学习/2021.2 MULocDeep-master/MULocDeep-master_new/model_result",
                       help='the name of the directory where the trained model stores', required=False)  #由True改成False
    
    parser.add_argument('-existPSSM', dest='existPSSM', type=str,
                        default="E:/论文真的非常重要请好好学习/2021.2 MULocDeep-master/MULocDeep-master_new/model_result/1615385705_pssm",
                        help='the name of the existing PSSM directory if there is one.', required=False)
    
    #var_model  deeploc_40nr_8folds
    #--input_dir 训练var模型的数据，包含8折蛋白质序列和标记  需自己添加
    parser.add_argument('--input_var', dest='var_dir', type=str,
                        default="D:/deeploc/deeploc_40nr_8folds",
                        help='data for traing the variant model, contains 8 folds protein sequences and labels', required=False)
    #改true  并且还需要加一个model_ouput  一个是deeploc  一个是MULocDeep
    parser.add_argument('--var_model_output', dest='var_outputdir', type=str, help='the name of the directory where the trained model stores', 
                        default="D:/deeploc/var_model_result3",
                        required=False)  #由True改成False
    parser.add_argument('-var_existPSSM', dest='var_existPSSM', type=str,
                        default="D:/deeploc/deeploc_pssm",
                        help='the name of the existing PSSM directory if there is one.', required=False)
    parser.set_defaults(feature=True)
    #args = parser.parse_args()   #改
    args = parser.parse_known_args()[0]   #jupyter下运行解析需要此代码
    model_type=args.modeltype
    input_lv1=args.lv1_dir
    input_lv2 = args.lv2_dir
    outputdir=args.outputdir
    existPSSM = args.existPSSM
    input_var=args.var_dir
    var_outputdir=args.var_outputdir
    var_existPSSM = args.var_existPSSM

    if model_type==True:
        if not input_lv1[len(input_lv1) - 1] == "/":
            input_lv1 = input_lv1 + "/"
        if not input_lv2[len(input_lv2) - 1] == "/":
            input_lv2 = input_lv2 + "/"
        if not outputdir[len(outputdir) - 1] == "/":
            outputdir = outputdir + "/"
        if not os.path.exists(outputdir):
            os.mkdir(outputdir)
        if existPSSM != "":
            if not existPSSM[len(existPSSM) - 1] == "/":
                existPSSM = existPSSM + "/"
        if ((existPSSM == "") or (not os.path.exists(existPSSM))):
            ts = calendar.timegm(time.gmtime())
            pssmdir = outputdir + str(ts) + "_pssm/"
            if not os.path.exists(pssmdir):
                os.makedirs(pssmdir)
            process_input_train(input_lv1 + "lv1_train.txt", pssmdir)
            process_input_train(input_lv2 + "lv2_train.txt", pssmdir)
            for foldnum in range(8):
                train_MULocDeep(input_lv1, input_lv2, pssmdir, outputdir, foldnum)
        else:
            for foldnum in range(8):
                train_MULocDeep(input_lv1, input_lv2, existPSSM, outputdir, foldnum)
    elif model_type==False:
        if not input_var[len(input_var) - 1] == "/":
            input_var = input_var + "/"
        if not var_outputdir[len(var_outputdir) - 1] == "/":
            var_outputdir = var_outputdir + "/"
        if not os.path.exists(var_outputdir):
            os.mkdir(var_outputdir)
        if existPSSM != "":
            if not var_existPSSM[len(var_existPSSM) - 1] == "/":
                var_existPSSM = var_existPSSM + "/"
        if ((var_existPSSM == "") or (not os.path.exists(var_existPSSM))):
            ts = calendar.timegm(time.gmtime())
            pssmdir = var_outputdir + str(ts) + "_pssm/"
            if not os.path.exists(pssmdir):
                os.makedirs(pssmdir)
            process_input_train(input_var + "processed_deeploc_train_S_seq", pssmdir)
            for foldnum in range(8):
                train_var(input_var, pssmdir, var_outputdir, foldnum)
        else:
            for foldnum in range(8):
                train_var(input_var, var_existPSSM, var_outputdir, foldnum)

# %%
if __name__ == "__main__":
    main()
# Out:
# doing 0th fold
# WARNING:tensorflow:From C:\Users\vipuser\.conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\vipuser\.conda\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 9533 samples, validate on 1552 samples
# Epoch 1/20
# 9533/9533 [==============================] - 67s 7ms/step - loss: 1.6136 - accuracy: 0.5314 - val_loss: 1.8172 - val_accuracy: 0.4639
#
# Epoch 00001: val_accuracy improved from -inf to 0.46392, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 2/20
# 9533/9533 [==============================] - 59s 6ms/step - loss: 1.3307 - accuracy: 0.6496 - val_loss: 1.5365 - val_accuracy: 0.5425
#
# Epoch 00002: val_accuracy improved from 0.46392 to 0.54253, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 3/20
# 9533/9533 [==============================] - 55s 6ms/step - loss: 1.1947 - accuracy: 0.6950 - val_loss: 1.3530 - val_accuracy: 0.6424
#
# Epoch 00003: val_accuracy improved from 0.54253 to 0.64240, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 4/20
# 9533/9533 [==============================] - 55s 6ms/step - loss: 1.1052 - accuracy: 0.7191 - val_loss: 1.0919 - val_accuracy: 0.7204
#
# Epoch 00004: val_accuracy improved from 0.64240 to 0.72036, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 5/20
# 9533/9533 [==============================] - 55s 6ms/step - loss: 1.0339 - accuracy: 0.7419 - val_loss: 1.0137 - val_accuracy: 0.7223
#
# Epoch 00005: val_accuracy improved from 0.72036 to 0.72229, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 6/20
# 9533/9533 [==============================] - 54s 6ms/step - loss: 0.9696 - accuracy: 0.7648 - val_loss: 0.9893 - val_accuracy: 0.7281
#
# Epoch 00006: val_accuracy improved from 0.72229 to 0.72809, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 7/20
# 9533/9533 [==============================] - 54s 6ms/step - loss: 0.8971 - accuracy: 0.7868 - val_loss: 0.9544 - val_accuracy: 0.7429
#
# Epoch 00007: val_accuracy improved from 0.72809 to 0.74291, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 8/20
# 9533/9533 [==============================] - 53s 6ms/step - loss: 0.8360 - accuracy: 0.8136 - val_loss: 0.9014 - val_accuracy: 0.7564
#
# Epoch 00008: val_accuracy improved from 0.74291 to 0.75644, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 9/20
# 9533/9533 [==============================] - 53s 6ms/step - loss: 0.7785 - accuracy: 0.8327 - val_loss: 0.9351 - val_accuracy: 0.7590
#
# Epoch 00009: val_accuracy improved from 0.75644 to 0.75902, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 10/20
# 9533/9533 [==============================] - 53s 6ms/step - loss: 0.7263 - accuracy: 0.8460 - val_loss: 0.8896 - val_accuracy: 0.7668
#
# Epoch 00010: val_accuracy improved from 0.75902 to 0.76675, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 11/20
# 9533/9533 [==============================] - 52s 5ms/step - loss: 0.6745 - accuracy: 0.8650 - val_loss: 0.9532 - val_accuracy: 0.7519
#
# Epoch 00011: val_accuracy did not improve from 0.76675
# Epoch 12/20
# 9533/9533 [==============================] - 52s 5ms/step - loss: 0.6284 - accuracy: 0.8807 - val_loss: 0.9541 - val_accuracy: 0.7397
#
# Epoch 00012: val_accuracy did not improve from 0.76675
# Epoch 13/20
# 9533/9533 [==============================] - 53s 6ms/step - loss: 0.5809 - accuracy: 0.8955 - val_loss: 0.8897 - val_accuracy: 0.7481
#
# Epoch 00013: val_accuracy did not improve from 0.76675
# Epoch 14/20
# 9533/9533 [==============================] - 53s 6ms/step - loss: 0.5327 - accuracy: 0.9093 - val_loss: 0.8703 - val_accuracy: 0.7558
#
# Epoch 00014: val_accuracy did not improve from 0.76675
# Epoch 15/20
# 9533/9533 [==============================] - 52s 5ms/step - loss: 0.4986 - accuracy: 0.9207 - val_loss: 0.9643 - val_accuracy: 0.7352
#
# Epoch 00015: val_accuracy did not improve from 0.76675
# Epoch 16/20
# 9533/9533 [==============================] - 53s 6ms/step - loss: 0.4659 - accuracy: 0.9320 - val_loss: 0.9370 - val_accuracy: 0.7423
#
# Epoch 00016: val_accuracy did not improve from 0.76675
# Epoch 17/20
# 9533/9533 [==============================] - 54s 6ms/step - loss: 0.4321 - accuracy: 0.9412 - val_loss: 0.8568 - val_accuracy: 0.7603
#
# Epoch 00017: val_accuracy did not improve from 0.76675
# Epoch 18/20
# 9533/9533 [==============================] - 54s 6ms/step - loss: 0.4075 - accuracy: 0.9462 - val_loss: 0.8567 - val_accuracy: 0.7680
#
# Epoch 00018: val_accuracy improved from 0.76675 to 0.76804, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# Epoch 19/20
# 9533/9533 [==============================] - 54s 6ms/step - loss: 0.3778 - accuracy: 0.9558 - val_loss: 0.8757 - val_accuracy: 0.7584
#
# Epoch 00019: val_accuracy did not improve from 0.76804
# Epoch 20/20
# 9533/9533 [==============================] - 54s 6ms/step - loss: 0.3560 - accuracy: 0.9597 - val_loss: 0.8667 - val_accuracy: 0.7745
#
# Epoch 00020: val_accuracy improved from 0.76804 to 0.77448, saving model to D:/deeploc/var_model_result3/fold0acc-weights.hdf5
# doing 1th fold
# Train on 9748 samples, validate on 1337 samples
# Epoch 1/20
# 9748/9748 [==============================] - 59s 6ms/step - loss: 1.5830 - accuracy: 0.5476 - val_loss: 1.8496 - val_accuracy: 0.3874
#
# Epoch 00001: val_accuracy improved from -inf to 0.38743, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 2/20
# 9748/9748 [==============================] - 56s 6ms/step - loss: 1.2978 - accuracy: 0.6667 - val_loss: 1.6395 - val_accuracy: 0.5123
#
# Epoch 00002: val_accuracy improved from 0.38743 to 0.51234, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 3/20
# 9748/9748 [==============================] - 54s 6ms/step - loss: 1.1732 - accuracy: 0.7033 - val_loss: 1.4572 - val_accuracy: 0.5333
#
# Epoch 00003: val_accuracy improved from 0.51234 to 0.53328, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 4/20
# 9748/9748 [==============================] - 53s 5ms/step - loss: 1.0839 - accuracy: 0.7318 - val_loss: 1.3741 - val_accuracy: 0.6006
#
# Epoch 00004: val_accuracy improved from 0.53328 to 0.60060, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 5/20
# 9748/9748 [==============================] - 54s 5ms/step - loss: 1.0098 - accuracy: 0.7577 - val_loss: 1.1915 - val_accuracy: 0.6574
#
# Epoch 00005: val_accuracy improved from 0.60060 to 0.65744, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 6/20
# 9748/9748 [==============================] - 53s 5ms/step - loss: 0.9577 - accuracy: 0.7700 - val_loss: 1.2278 - val_accuracy: 0.6380
#
# Epoch 00006: val_accuracy did not improve from 0.65744
# Epoch 7/20
# 9748/9748 [==============================] - 54s 6ms/step - loss: 0.8843 - accuracy: 0.7963 - val_loss: 1.1067 - val_accuracy: 0.6806
#
# Epoch 00007: val_accuracy improved from 0.65744 to 0.68063, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 8/20
# 9748/9748 [==============================] - 54s 6ms/step - loss: 0.8167 - accuracy: 0.8169 - val_loss: 1.0703 - val_accuracy: 0.6859
#
# Epoch 00008: val_accuracy improved from 0.68063 to 0.68586, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 9/20
# 9748/9748 [==============================] - 53s 5ms/step - loss: 0.7651 - accuracy: 0.8314 - val_loss: 1.0176 - val_accuracy: 0.6978
#
# Epoch 00009: val_accuracy improved from 0.68586 to 0.69783, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 10/20
# 9748/9748 [==============================] - 54s 6ms/step - loss: 0.7119 - accuracy: 0.8549 - val_loss: 0.9696 - val_accuracy: 0.7113
#
# Epoch 00010: val_accuracy improved from 0.69783 to 0.71129, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 11/20
# 9748/9748 [==============================] - 53s 5ms/step - loss: 0.6670 - accuracy: 0.8628 - val_loss: 1.0182 - val_accuracy: 0.6933
#
# Epoch 00011: val_accuracy did not improve from 0.71129
# Epoch 12/20
# 9748/9748 [==============================] - 53s 5ms/step - loss: 0.6172 - accuracy: 0.8818 - val_loss: 1.0215 - val_accuracy: 0.7038
#
# Epoch 00012: val_accuracy did not improve from 0.71129
# Epoch 13/20
# 9748/9748 [==============================] - 54s 6ms/step - loss: 0.5692 - accuracy: 0.9002 - val_loss: 0.9901 - val_accuracy: 0.7076
#
# Epoch 00013: val_accuracy did not improve from 0.71129
# Epoch 14/20
# 9748/9748 [==============================] - 54s 5ms/step - loss: 0.5319 - accuracy: 0.9094 - val_loss: 1.0940 - val_accuracy: 0.6791
#
# Epoch 00014: val_accuracy did not improve from 0.71129
# Epoch 15/20
# 9748/9748 [==============================] - 53s 5ms/step - loss: 0.4949 - accuracy: 0.9224 - val_loss: 0.9773 - val_accuracy: 0.7083
#
# Epoch 00015: val_accuracy did not improve from 0.71129
# Epoch 16/20
# 9748/9748 [==============================] - 53s 5ms/step - loss: 0.4604 - accuracy: 0.9281 - val_loss: 0.9975 - val_accuracy: 0.6874
#
# Epoch 00016: val_accuracy did not improve from 0.71129
# Epoch 17/20
# 9748/9748 [==============================] - 53s 5ms/step - loss: 0.4326 - accuracy: 0.9390 - val_loss: 0.9599 - val_accuracy: 0.7218
#
# Epoch 00017: val_accuracy improved from 0.71129 to 0.72177, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 18/20
# 9748/9748 [==============================] - 53s 5ms/step - loss: 0.4019 - accuracy: 0.9460 - val_loss: 0.9558 - val_accuracy: 0.7330
#
# Epoch 00018: val_accuracy improved from 0.72177 to 0.73298, saving model to D:/deeploc/var_model_result3/fold1acc-weights.hdf5
# Epoch 19/20
# 9748/9748 [==============================] - 54s 6ms/step - loss: 0.3709 - accuracy: 0.9541 - val_loss: 1.0298 - val_accuracy: 0.6889
#
# Epoch 00019: val_accuracy did not improve from 0.73298
# Epoch 20/20
# 9748/9748 [==============================] - 54s 6ms/step - loss: 0.3523 - accuracy: 0.9564 - val_loss: 0.9259 - val_accuracy: 0.7300
#
# Epoch 00020: val_accuracy did not improve from 0.73298
# doing 2th fold
# Train on 9641 samples, validate on 1444 samples
# Epoch 1/20
# 9641/9641 [==============================] - 61s 6ms/step - loss: 1.5942 - accuracy: 0.5420 - val_loss: 1.8114 - val_accuracy: 0.3996
#
# Epoch 00001: val_accuracy improved from -inf to 0.39958, saving model to D:/deeploc/var_model_result3/fold2acc-weights.hdf5
# Epoch 2/20
# 9641/9641 [==============================] - 57s 6ms/step - loss: 1.3071 - accuracy: 0.6626 - val_loss: 1.5655 - val_accuracy: 0.4758
#
# Epoch 00002: val_accuracy improved from 0.39958 to 0.47576, saving model to D:/deeploc/var_model_result3/fold2acc-weights.hdf5
# Epoch 3/20
# 9641/9641 [==============================] - 57s 6ms/step - loss: 1.1756 - accuracy: 0.7055 - val_loss: 1.3700 - val_accuracy: 0.5713
#
# Epoch 00003: val_accuracy improved from 0.47576 to 0.57133, saving model to D:/deeploc/var_model_result3/fold2acc-weights.hdf5
# Epoch 4/20
# 9641/9641 [==============================] - 56s 6ms/step - loss: 1.0901 - accuracy: 0.7289 - val_loss: 1.1988 - val_accuracy: 0.6745
#
# Epoch 00004: val_accuracy improved from 0.57133 to 0.67452, saving model to D:/deeploc/var_model_result3/fold2acc-weights.hdf5
# Epoch 5/20
# 9641/9641 [==============================] - 56s 6ms/step - loss: 1.0125 - accuracy: 0.7602 - val_loss: 1.1003 - val_accuracy: 0.6690
#
# Epoch 00005: val_accuracy did not improve from 0.67452
# Epoch 6/20
# 9641/9641 [==============================] - 58s 6ms/step - loss: 0.9405 - accuracy: 0.7789 - val_loss: 1.1101 - val_accuracy: 0.6731
#
# Epoch 00006: val_accuracy did not improve from 0.67452
# Epoch 7/20
# 9641/9641 [==============================] - 56s 6ms/step - loss: 0.8799 - accuracy: 0.7989 - val_loss: 1.0113 - val_accuracy: 0.7230
#
# Epoch 00007: val_accuracy improved from 0.67452 to 0.72299, saving model to D:/deeploc/var_model_result3/fold2acc-weights.hdf5
# Epoch 8/20
# 9641/9641 [==============================] - 55s 6ms/step - loss: 0.8267 - accuracy: 0.8138 - val_loss: 1.0133 - val_accuracy: 0.7161
#
# Epoch 00008: val_accuracy did not improve from 0.72299
# Epoch 9/20
# 9641/9641 [==============================] - 56s 6ms/step - loss: 0.7634 - accuracy: 0.8365 - val_loss: 0.9892 - val_accuracy: 0.7341
#
# Epoch 00009: val_accuracy improved from 0.72299 to 0.73407, saving model to D:/deeploc/var_model_result3/fold2acc-weights.hdf5
# Epoch 10/20
# 9641/9641 [==============================] - 56s 6ms/step - loss: 0.7154 - accuracy: 0.8552 - val_loss: 0.9664 - val_accuracy: 0.7140
#
# Epoch 00010: val_accuracy did not improve from 0.73407
# Epoch 11/20
# 9641/9641 [==============================] - 57s 6ms/step - loss: 0.6539 - accuracy: 0.8771 - val_loss: 0.9622 - val_accuracy: 0.7216
#
# Epoch 00011: val_accuracy did not improve from 0.73407
# Epoch 12/20
# 9641/9641 [==============================] - 58s 6ms/step - loss: 0.6116 - accuracy: 0.8908 - val_loss: 1.0751 - val_accuracy: 0.6863
#
# Epoch 00012: val_accuracy did not improve from 0.73407
# Epoch 13/20
# 9641/9641 [==============================] - 55s 6ms/step - loss: 0.5702 - accuracy: 0.9010 - val_loss: 0.9533 - val_accuracy: 0.7368
#
# Epoch 00013: val_accuracy improved from 0.73407 to 0.73684, saving model to D:/deeploc/var_model_result3/fold2acc-weights.hdf5
# Epoch 14/20
# 9641/9641 [==============================] - 55s 6ms/step - loss: 0.5313 - accuracy: 0.9108 - val_loss: 0.9697 - val_accuracy: 0.7320
#
# Epoch 00014: val_accuracy did not improve from 0.73684
# Epoch 15/20
# 9641/9641 [==============================] - 55s 6ms/step - loss: 0.4919 - accuracy: 0.9276 - val_loss: 0.9032 - val_accuracy: 0.7445
#
# Epoch 00015: val_accuracy improved from 0.73684 to 0.74446, saving model to D:/deeploc/var_model_result3/fold2acc-weights.hdf5
# Epoch 16/20
# 9641/9641 [==============================] - 55s 6ms/step - loss: 0.4656 - accuracy: 0.9293 - val_loss: 0.9211 - val_accuracy: 0.7410
#
# Epoch 00016: val_accuracy did not improve from 0.74446
# Epoch 17/20
# 9641/9641 [==============================] - 54s 6ms/step - loss: 0.4349 - accuracy: 0.9409 - val_loss: 0.9425 - val_accuracy: 0.7202
#
# Epoch 00017: val_accuracy did not improve from 0.74446
# Epoch 18/20
# 9641/9641 [==============================] - 54s 6ms/step - loss: 0.4016 - accuracy: 0.9521 - val_loss: 0.9327 - val_accuracy: 0.7382
#
# Epoch 00018: val_accuracy did not improve from 0.74446
# Epoch 19/20
# 9641/9641 [==============================] - 55s 6ms/step - loss: 0.3732 - accuracy: 0.9556 - val_loss: 0.8868 - val_accuracy: 0.7479
#
# Epoch 00019: val_accuracy improved from 0.74446 to 0.74792, saving model to D:/deeploc/var_model_result3/fold2acc-weights.hdf5
# Epoch 20/20
# 9641/9641 [==============================] - 54s 6ms/step - loss: 0.3543 - accuracy: 0.9591 - val_loss: 0.9402 - val_accuracy: 0.7334
#
# Epoch 00020: val_accuracy did not improve from 0.74792
# doing 3th fold
# Train on 9701 samples, validate on 1384 samples
# Epoch 1/20
# 9701/9701 [==============================] - 61s 6ms/step - loss: 1.5970 - accuracy: 0.5427 - val_loss: 1.9264 - val_accuracy: 0.2753
#
# Epoch 00001: val_accuracy improved from -inf to 0.27529, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 2/20
# 9701/9701 [==============================] - 56s 6ms/step - loss: 1.3110 - accuracy: 0.6637 - val_loss: 1.6117 - val_accuracy: 0.5036
#
# Epoch 00002: val_accuracy improved from 0.27529 to 0.50361, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 3/20
# 9701/9701 [==============================] - 56s 6ms/step - loss: 1.1791 - accuracy: 0.7053 - val_loss: 1.5174 - val_accuracy: 0.4841
#
# Epoch 00003: val_accuracy did not improve from 0.50361
# Epoch 4/20
# 9701/9701 [==============================] - 56s 6ms/step - loss: 1.0926 - accuracy: 0.7295 - val_loss: 1.1644 - val_accuracy: 0.6720
#
# Epoch 00004: val_accuracy improved from 0.50361 to 0.67197, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 5/20
# 9701/9701 [==============================] - 56s 6ms/step - loss: 1.0201 - accuracy: 0.7495 - val_loss: 1.2157 - val_accuracy: 0.6127
#
# Epoch 00005: val_accuracy did not improve from 0.67197
# Epoch 6/20
# 9701/9701 [==============================] - 56s 6ms/step - loss: 0.9549 - accuracy: 0.7702 - val_loss: 1.0425 - val_accuracy: 0.6980
#
# Epoch 00006: val_accuracy improved from 0.67197 to 0.69798, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 7/20
# 9701/9701 [==============================] - 56s 6ms/step - loss: 0.8839 - accuracy: 0.7997 - val_loss: 1.0199 - val_accuracy: 0.7001
#
# Epoch 00007: val_accuracy improved from 0.69798 to 0.70014, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 8/20
# 9701/9701 [==============================] - 56s 6ms/step - loss: 0.8314 - accuracy: 0.8168 - val_loss: 1.0310 - val_accuracy: 0.7045
#
# Epoch 00008: val_accuracy improved from 0.70014 to 0.70448, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 9/20
# 9701/9701 [==============================] - 55s 6ms/step - loss: 0.7712 - accuracy: 0.8345 - val_loss: 0.9454 - val_accuracy: 0.7283
#
# Epoch 00009: val_accuracy improved from 0.70448 to 0.72832, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 10/20
# 9701/9701 [==============================] - 55s 6ms/step - loss: 0.7181 - accuracy: 0.8524 - val_loss: 1.0255 - val_accuracy: 0.7160
#
# Epoch 00010: val_accuracy did not improve from 0.72832
# Epoch 11/20
# 9701/9701 [==============================] - 55s 6ms/step - loss: 0.6677 - accuracy: 0.8635 - val_loss: 0.9545 - val_accuracy: 0.7276
#
# Epoch 00011: val_accuracy did not improve from 0.72832
# Epoch 12/20
# 9701/9701 [==============================] - 54s 6ms/step - loss: 0.6161 - accuracy: 0.8870 - val_loss: 1.0190 - val_accuracy: 0.7001
#
# Epoch 00012: val_accuracy did not improve from 0.72832
# Epoch 13/20
# 9701/9701 [==============================] - 54s 6ms/step - loss: 0.5759 - accuracy: 0.8959 - val_loss: 0.9391 - val_accuracy: 0.7327
#
# Epoch 00013: val_accuracy improved from 0.72832 to 0.73266, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 14/20
# 9701/9701 [==============================] - 55s 6ms/step - loss: 0.5314 - accuracy: 0.9092 - val_loss: 0.9595 - val_accuracy: 0.7305
#
# Epoch 00014: val_accuracy did not improve from 0.73266
# Epoch 15/20
# 9701/9701 [==============================] - 54s 6ms/step - loss: 0.4961 - accuracy: 0.9195 - val_loss: 0.9370 - val_accuracy: 0.7334
#
# Epoch 00015: val_accuracy improved from 0.73266 to 0.73338, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 16/20
# 9701/9701 [==============================] - 54s 6ms/step - loss: 0.4672 - accuracy: 0.9287 - val_loss: 0.9326 - val_accuracy: 0.7182
#
# Epoch 00016: val_accuracy did not improve from 0.73338
# Epoch 17/20
# 9701/9701 [==============================] - 55s 6ms/step - loss: 0.4332 - accuracy: 0.9409 - val_loss: 0.9137 - val_accuracy: 0.7442
#
# Epoch 00017: val_accuracy improved from 0.73338 to 0.74422, saving model to D:/deeploc/var_model_result3/fold3acc-weights.hdf5
# Epoch 18/20
# 9701/9701 [==============================] - 54s 6ms/step - loss: 0.3996 - accuracy: 0.9476 - val_loss: 0.9014 - val_accuracy: 0.7363
#
# Epoch 00018: val_accuracy did not improve from 0.74422
# Epoch 19/20
# 9701/9701 [==============================] - 55s 6ms/step - loss: 0.3753 - accuracy: 0.9552 - val_loss: 0.9475 - val_accuracy: 0.7312
#
# Epoch 00019: val_accuracy did not improve from 0.74422
# Epoch 20/20
# 9701/9701 [==============================] - 55s 6ms/step - loss: 0.3511 - accuracy: 0.9605 - val_loss: 0.8993 - val_accuracy: 0.7377
#
# Epoch 00020: val_accuracy did not improve from 0.74422
# doing 4th fold
# Train on 9739 samples, validate on 1346 samples
# Epoch 1/20
# 9739/9739 [==============================] - 63s 6ms/step - loss: 1.5888 - accuracy: 0.5423 - val_loss: 1.7751 - val_accuracy: 0.4019
#
# Epoch 00001: val_accuracy improved from -inf to 0.40193, saving model to D:/deeploc/var_model_result3/fold4acc-weights.hdf5
# Epoch 2/20
# 9739/9739 [==============================] - 57s 6ms/step - loss: 1.3120 - accuracy: 0.6563 - val_loss: 1.5907 - val_accuracy: 0.5817
#
# Epoch 00002: val_accuracy improved from 0.40193 to 0.58172, saving model to D:/deeploc/var_model_result3/fold4acc-weights.hdf5
# Epoch 3/20
# 9739/9739 [==============================] - 57s 6ms/step - loss: 1.1821 - accuracy: 0.6978 - val_loss: 1.2902 - val_accuracy: 0.6367
#
# Epoch 00003: val_accuracy improved from 0.58172 to 0.63670, saving model to D:/deeploc/var_model_result3/fold4acc-weights.hdf5
# Epoch 4/20
# 9739/9739 [==============================] - 57s 6ms/step - loss: 1.0889 - accuracy: 0.7284 - val_loss: 1.1237 - val_accuracy: 0.6909
#
# Epoch 00004: val_accuracy improved from 0.63670 to 0.69094, saving model to D:/deeploc/var_model_result3/fold4acc-weights.hdf5
# Epoch 5/20
# 9739/9739 [==============================] - 57s 6ms/step - loss: 1.0255 - accuracy: 0.7473 - val_loss: 1.1204 - val_accuracy: 0.6865
#
# Epoch 00005: val_accuracy did not improve from 0.69094
# Epoch 6/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.9601 - accuracy: 0.7681 - val_loss: 1.0280 - val_accuracy: 0.7110
#
# Epoch 00006: val_accuracy improved from 0.69094 to 0.71100, saving model to D:/deeploc/var_model_result3/fold4acc-weights.hdf5
# Epoch 7/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.9009 - accuracy: 0.7871 - val_loss: 1.0366 - val_accuracy: 0.6976
#
# Epoch 00007: val_accuracy did not improve from 0.71100
# Epoch 8/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.8434 - accuracy: 0.8014 - val_loss: 1.0503 - val_accuracy: 0.7132
#
# Epoch 00008: val_accuracy improved from 0.71100 to 0.71322, saving model to D:/deeploc/var_model_result3/fold4acc-weights.hdf5
# Epoch 9/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.7908 - accuracy: 0.8230 - val_loss: 1.0634 - val_accuracy: 0.7103
#
# Epoch 00009: val_accuracy did not improve from 0.71322
# Epoch 10/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.7372 - accuracy: 0.8376 - val_loss: 1.1040 - val_accuracy: 0.6872
#
# Epoch 00010: val_accuracy did not improve from 0.71322
# Epoch 11/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.6876 - accuracy: 0.8572 - val_loss: 1.0702 - val_accuracy: 0.7095
#
# Epoch 00011: val_accuracy did not improve from 0.71322
# Epoch 12/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.6456 - accuracy: 0.8684 - val_loss: 0.9370 - val_accuracy: 0.7303
#
# Epoch 00012: val_accuracy improved from 0.71322 to 0.73031, saving model to D:/deeploc/var_model_result3/fold4acc-weights.hdf5
# Epoch 13/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.5926 - accuracy: 0.8852 - val_loss: 0.9990 - val_accuracy: 0.7036
#
# Epoch 00013: val_accuracy did not improve from 0.73031
# Epoch 14/20
# 9739/9739 [==============================] - 56s 6ms/step - loss: 0.5642 - accuracy: 0.8953 - val_loss: 0.9391 - val_accuracy: 0.7266
#
# Epoch 00014: val_accuracy did not improve from 0.73031
# Epoch 15/20
# 9739/9739 [==============================] - 56s 6ms/step - loss: 0.5123 - accuracy: 0.9105 - val_loss: 0.9923 - val_accuracy: 0.7221
#
# Epoch 00015: val_accuracy did not improve from 0.73031
# Epoch 16/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.4879 - accuracy: 0.9182 - val_loss: 0.8988 - val_accuracy: 0.7385
#
# Epoch 00016: val_accuracy improved from 0.73031 to 0.73848, saving model to D:/deeploc/var_model_result3/fold4acc-weights.hdf5
# Epoch 17/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.4534 - accuracy: 0.9273 - val_loss: 1.0306 - val_accuracy: 0.7073
#
# Epoch 00017: val_accuracy did not improve from 0.73848
# Epoch 18/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.4200 - accuracy: 0.9381 - val_loss: 0.9244 - val_accuracy: 0.7333
#
# Epoch 00018: val_accuracy did not improve from 0.73848
# Epoch 19/20
# 9739/9739 [==============================] - 55s 6ms/step - loss: 0.3936 - accuracy: 0.9470 - val_loss: 0.9492 - val_accuracy: 0.7348
#
# Epoch 00019: val_accuracy did not improve from 0.73848
# Epoch 20/20
# 9739/9739 [==============================] - 57s 6ms/step - loss: 0.3741 - accuracy: 0.9500 - val_loss: 0.9125 - val_accuracy: 0.7377
#
# Epoch 00020: val_accuracy did not improve from 0.73848
# doing 5th fold
# Train on 9762 samples, validate on 1323 samples
# Epoch 1/20
# 9762/9762 [==============================] - 63s 6ms/step - loss: 1.5919 - accuracy: 0.5412 - val_loss: 1.8325 - val_accuracy: 0.4331
#
# Epoch 00001: val_accuracy improved from -inf to 0.43311, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 2/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 1.2968 - accuracy: 0.6612 - val_loss: 1.6342 - val_accuracy: 0.4263
#
# Epoch 00002: val_accuracy did not improve from 0.43311
# Epoch 3/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 1.1672 - accuracy: 0.7040 - val_loss: 1.4683 - val_accuracy: 0.5631
#
# Epoch 00003: val_accuracy improved from 0.43311 to 0.56311, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 4/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 1.0806 - accuracy: 0.7336 - val_loss: 1.3386 - val_accuracy: 0.5865
#
# Epoch 00004: val_accuracy improved from 0.56311 to 0.58655, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 5/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 1.0122 - accuracy: 0.7503 - val_loss: 1.0880 - val_accuracy: 0.6924
#
# Epoch 00005: val_accuracy improved from 0.58655 to 0.69237, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 6/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.9436 - accuracy: 0.7712 - val_loss: 1.0826 - val_accuracy: 0.7075
#
# Epoch 00006: val_accuracy improved from 0.69237 to 0.70748, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 7/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.8818 - accuracy: 0.7984 - val_loss: 1.0376 - val_accuracy: 0.7090
#
# Epoch 00007: val_accuracy improved from 0.70748 to 0.70899, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 8/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.8235 - accuracy: 0.8148 - val_loss: 0.9840 - val_accuracy: 0.7256
#
# Epoch 00008: val_accuracy improved from 0.70899 to 0.72562, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 9/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.7729 - accuracy: 0.8269 - val_loss: 1.0631 - val_accuracy: 0.7113
#
# Epoch 00009: val_accuracy did not improve from 0.72562
# Epoch 10/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.7191 - accuracy: 0.8462 - val_loss: 1.0473 - val_accuracy: 0.7181
#
# Epoch 00010: val_accuracy did not improve from 0.72562
# Epoch 11/20
# 9762/9762 [==============================] - 56s 6ms/step - loss: 0.6629 - accuracy: 0.8646 - val_loss: 0.9807 - val_accuracy: 0.7309
#
# Epoch 00011: val_accuracy improved from 0.72562 to 0.73091, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 12/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.6134 - accuracy: 0.8791 - val_loss: 0.9789 - val_accuracy: 0.7286
#
# Epoch 00012: val_accuracy did not improve from 0.73091
# Epoch 13/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.5741 - accuracy: 0.8922 - val_loss: 0.9905 - val_accuracy: 0.7128
#
# Epoch 00013: val_accuracy did not improve from 0.73091
# Epoch 14/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.5387 - accuracy: 0.9030 - val_loss: 0.9797 - val_accuracy: 0.7271
#
# Epoch 00014: val_accuracy did not improve from 0.73091
# Epoch 15/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.5017 - accuracy: 0.9161 - val_loss: 1.0385 - val_accuracy: 0.7128
#
# Epoch 00015: val_accuracy did not improve from 0.73091
# Epoch 16/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.4655 - accuracy: 0.9251 - val_loss: 1.0117 - val_accuracy: 0.7226
#
# Epoch 00016: val_accuracy did not improve from 0.73091
# Epoch 17/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.4311 - accuracy: 0.9379 - val_loss: 0.9381 - val_accuracy: 0.7332
#
# Epoch 00017: val_accuracy improved from 0.73091 to 0.73318, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 18/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.4063 - accuracy: 0.9440 - val_loss: 0.9364 - val_accuracy: 0.7407
#
# Epoch 00018: val_accuracy improved from 0.73318 to 0.74074, saving model to D:/deeploc/var_model_result3/fold5acc-weights.hdf5
# Epoch 19/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.3787 - accuracy: 0.9520 - val_loss: 0.9662 - val_accuracy: 0.7392
#
# Epoch 00019: val_accuracy did not improve from 0.74074
# Epoch 20/20
# 9762/9762 [==============================] - 57s 6ms/step - loss: 0.3523 - accuracy: 0.9599 - val_loss: 1.0267 - val_accuracy: 0.7234
#
# Epoch 00020: val_accuracy did not improve from 0.74074
# doing 6th fold
# Train on 9677 samples, validate on 1408 samples
# Epoch 1/20
# 9677/9677 [==============================] - 62s 6ms/step - loss: 1.5914 - accuracy: 0.5470 - val_loss: 1.8665 - val_accuracy: 0.3203
#
# Epoch 00001: val_accuracy improved from -inf to 0.32031, saving model to D:/deeploc/var_model_result3/fold6acc-weights.hdf5
# Epoch 2/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 1.2957 - accuracy: 0.6640 - val_loss: 1.5990 - val_accuracy: 0.4915
#
# Epoch 00002: val_accuracy improved from 0.32031 to 0.49148, saving model to D:/deeploc/var_model_result3/fold6acc-weights.hdf5
# Epoch 3/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 1.1655 - accuracy: 0.7097 - val_loss: 1.5024 - val_accuracy: 0.4893
#
# Epoch 00003: val_accuracy did not improve from 0.49148
# Epoch 4/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 1.0778 - accuracy: 0.7311 - val_loss: 1.1869 - val_accuracy: 0.6399
#
# Epoch 00004: val_accuracy improved from 0.49148 to 0.63991, saving model to D:/deeploc/var_model_result3/fold6acc-weights.hdf5
# Epoch 5/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 0.9988 - accuracy: 0.7590 - val_loss: 1.1017 - val_accuracy: 0.6825
#
# Epoch 00005: val_accuracy improved from 0.63991 to 0.68253, saving model to D:/deeploc/var_model_result3/fold6acc-weights.hdf5
# Epoch 6/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 0.9455 - accuracy: 0.7748 - val_loss: 1.0815 - val_accuracy: 0.6797
#
# Epoch 00006: val_accuracy did not improve from 0.68253
# Epoch 7/20
# 9677/9677 [==============================] - 56s 6ms/step - loss: 0.8699 - accuracy: 0.8002 - val_loss: 1.0150 - val_accuracy: 0.6960
#
# Epoch 00007: val_accuracy improved from 0.68253 to 0.69602, saving model to D:/deeploc/var_model_result3/fold6acc-weights.hdf5
# Epoch 8/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 0.8149 - accuracy: 0.8201 - val_loss: 1.0156 - val_accuracy: 0.7195
#
# Epoch 00008: val_accuracy improved from 0.69602 to 0.71946, saving model to D:/deeploc/var_model_result3/fold6acc-weights.hdf5
# Epoch 9/20
# 9677/9677 [==============================] - 56s 6ms/step - loss: 0.7596 - accuracy: 0.8362 - val_loss: 0.9916 - val_accuracy: 0.7131
#
# Epoch 00009: val_accuracy did not improve from 0.71946
# Epoch 10/20
# 9677/9677 [==============================] - 56s 6ms/step - loss: 0.7029 - accuracy: 0.8514 - val_loss: 1.0640 - val_accuracy: 0.6839
#
# Epoch 00010: val_accuracy did not improve from 0.71946
# Epoch 11/20
# 9677/9677 [==============================] - 55s 6ms/step - loss: 0.6576 - accuracy: 0.8713 - val_loss: 1.0410 - val_accuracy: 0.6932
#
# Epoch 00011: val_accuracy did not improve from 0.71946
# Epoch 12/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 0.6028 - accuracy: 0.8924 - val_loss: 0.9856 - val_accuracy: 0.7166
#
# Epoch 00012: val_accuracy did not improve from 0.71946
# Epoch 13/20
# 9677/9677 [==============================] - 56s 6ms/step - loss: 0.5662 - accuracy: 0.8978 - val_loss: 0.9825 - val_accuracy: 0.6982
#
# Epoch 00013: val_accuracy did not improve from 0.71946
# Epoch 14/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 0.5250 - accuracy: 0.9145 - val_loss: 1.0423 - val_accuracy: 0.6818
#
# Epoch 00014: val_accuracy did not improve from 0.71946
# Epoch 15/20
# 9677/9677 [==============================] - 56s 6ms/step - loss: 0.4949 - accuracy: 0.9225 - val_loss: 0.9701 - val_accuracy: 0.7159
#
# Epoch 00015: val_accuracy did not improve from 0.71946
# Epoch 16/20
# 9677/9677 [==============================] - 56s 6ms/step - loss: 0.4548 - accuracy: 0.9352 - val_loss: 0.9354 - val_accuracy: 0.7308
#
# Epoch 00016: val_accuracy improved from 0.71946 to 0.73082, saving model to D:/deeploc/var_model_result3/fold6acc-weights.hdf5
# Epoch 17/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 0.4186 - accuracy: 0.9453 - val_loss: 1.0375 - val_accuracy: 0.6818
#
# Epoch 00017: val_accuracy did not improve from 0.73082
# Epoch 18/20
# 9677/9677 [==============================] - 57s 6ms/step - loss: 0.3883 - accuracy: 0.9531 - val_loss: 1.0076 - val_accuracy: 0.7159
#
# Epoch 00018: val_accuracy did not improve from 0.73082
# Epoch 19/20
# 9677/9677 [==============================] - 55s 6ms/step - loss: 0.3649 - accuracy: 0.9603 - val_loss: 0.9594 - val_accuracy: 0.7230
#
# Epoch 00019: val_accuracy did not improve from 0.73082
# Epoch 20/20
# 9677/9677 [==============================] - 55s 6ms/step - loss: 0.3438 - accuracy: 0.9615 - val_loss: 0.9272 - val_accuracy: 0.7358
#
# Epoch 00020: val_accuracy improved from 0.73082 to 0.73580, saving model to D:/deeploc/var_model_result3/fold6acc-weights.hdf5
# doing 7th fold
# Train on 9794 samples, validate on 1291 samples
# Epoch 1/20
# 9794/9794 [==============================] - 62s 6ms/step - loss: 1.5892 - accuracy: 0.5407 - val_loss: 1.7811 - val_accuracy: 0.3865
#
# Epoch 00001: val_accuracy improved from -inf to 0.38652, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 2/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 1.2982 - accuracy: 0.6643 - val_loss: 1.5345 - val_accuracy: 0.5523
#
# Epoch 00002: val_accuracy improved from 0.38652 to 0.55229, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 3/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 1.1700 - accuracy: 0.7027 - val_loss: 1.3282 - val_accuracy: 0.5716
#
# Epoch 00003: val_accuracy improved from 0.55229 to 0.57165, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 4/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 1.0846 - accuracy: 0.7312 - val_loss: 1.0841 - val_accuracy: 0.7080
#
# Epoch 00004: val_accuracy improved from 0.57165 to 0.70798, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 5/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 1.0036 - accuracy: 0.7567 - val_loss: 0.9963 - val_accuracy: 0.7103
#
# Epoch 00005: val_accuracy improved from 0.70798 to 0.71030, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 6/20
# 9794/9794 [==============================] - 56s 6ms/step - loss: 0.9414 - accuracy: 0.7811 - val_loss: 1.1935 - val_accuracy: 0.6212
#
# Epoch 00006: val_accuracy did not improve from 0.71030
# Epoch 7/20
# 9794/9794 [==============================] - 58s 6ms/step - loss: 0.8787 - accuracy: 0.7963 - val_loss: 1.0662 - val_accuracy: 0.7196
#
# Epoch 00007: val_accuracy improved from 0.71030 to 0.71960, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 8/20
# 9794/9794 [==============================] - 56s 6ms/step - loss: 0.8170 - accuracy: 0.8186 - val_loss: 0.9526 - val_accuracy: 0.7242
#
# Epoch 00008: val_accuracy improved from 0.71960 to 0.72424, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 9/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 0.7569 - accuracy: 0.8355 - val_loss: 0.9360 - val_accuracy: 0.7157
#
# Epoch 00009: val_accuracy did not improve from 0.72424
# Epoch 10/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 0.7089 - accuracy: 0.8510 - val_loss: 0.9400 - val_accuracy: 0.7281
#
# Epoch 00010: val_accuracy improved from 0.72424 to 0.72812, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 11/20
# 9794/9794 [==============================] - 56s 6ms/step - loss: 0.6502 - accuracy: 0.8757 - val_loss: 0.9414 - val_accuracy: 0.7374
#
# Epoch 00011: val_accuracy improved from 0.72812 to 0.73741, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 12/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 0.6091 - accuracy: 0.8836 - val_loss: 0.9286 - val_accuracy: 0.7428
#
# Epoch 00012: val_accuracy improved from 0.73741 to 0.74283, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 13/20
# 9794/9794 [==============================] - 56s 6ms/step - loss: 0.5659 - accuracy: 0.8996 - val_loss: 1.0280 - val_accuracy: 0.7033
#
# Epoch 00013: val_accuracy did not improve from 0.74283
# Epoch 14/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 0.5219 - accuracy: 0.9109 - val_loss: 0.9528 - val_accuracy: 0.7250
#
# Epoch 00014: val_accuracy did not improve from 0.74283
# Epoch 15/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 0.4863 - accuracy: 0.9254 - val_loss: 0.9336 - val_accuracy: 0.7421
#
# Epoch 00015: val_accuracy did not improve from 0.74283
# Epoch 16/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 0.4532 - accuracy: 0.9330 - val_loss: 0.8870 - val_accuracy: 0.7452
#
# Epoch 00016: val_accuracy improved from 0.74283 to 0.74516, saving model to D:/deeploc/var_model_result3/fold7acc-weights.hdf5
# Epoch 17/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 0.4172 - accuracy: 0.9438 - val_loss: 0.9128 - val_accuracy: 0.7421
#
# Epoch 00017: val_accuracy did not improve from 0.74516
# Epoch 18/20
# 9794/9794 [==============================] - 58s 6ms/step - loss: 0.3977 - accuracy: 0.9459 - val_loss: 0.9384 - val_accuracy: 0.7297
#
# Epoch 00018: val_accuracy did not improve from 0.74516
# Epoch 19/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 0.3673 - accuracy: 0.9550 - val_loss: 0.8971 - val_accuracy: 0.7382
#
# Epoch 00019: val_accuracy did not improve from 0.74516
# Epoch 20/20
# 9794/9794 [==============================] - 57s 6ms/step - loss: 0.3516 - accuracy: 0.9599 - val_loss: 0.9618 - val_accuracy: 0.7351
#
# Epoch 00020: val_accuracy did not improve from 0.74516
